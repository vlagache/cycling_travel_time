# %%
# %%capture
# %run data_analysis.ipynb

# %%
import warnings
warnings.filterwarnings('ignore')
from datetime import timedelta, date

# %% [markdown]
# ## Features Engineering
#
# Idées
#
# * Nombre d'activités dernier 30 jours avant aujourd'hui
# * Ecart de jour depuis la derniere activité ou en heure ( récupération ? )
# * Moyenne 30 derniers jours speed , heart_rate , watts , calories , suffer_score ?
# * Home Trainer ou pas
# * Heure de la journée de début ? =)
# * Mois de l'année ( meilleure performance , hiver été etc... )

# %% [markdown]
# **Nombres d'activités dernier 30 jours avant aujourd'hui**
#
# Erreur si on fait plusieurs activitées le meme jour... mais cas marginal

# %%
# def activities_last_30d(segments, activities):
#     nb_activities_last_30d = []
#     for date in segments['start_date']:
#         end_date = date - timedelta(days=1)
#         start_date = end_date - timedelta(days=30)
#         result = len(activities[activities['start_date'].between(start_date,end_date)])
#         nb_activities_last_30d.append(result)
#     segments['nb_activities_last_30d'] = nb_activities_last_30d
#     return segments

# %%
# segments = activities_last_30d(segments_df, activities_df)

# %%
# plt.style.use('dark_background')
# plt.figure(figsize=(15,8))
# plt.plot(segments_df['start_date'],segments_df['nb_activities_last_30d'])
# plt.xlabel('start_date')
# plt.ylabel('nb_activities_last_30d')
# plt.show()

# %% [markdown]
# **Home Trainer ou pas**

# %%
segments_df = pd.get_dummies(segments_df, columns=['type'], drop_first=True)
segments_df = segments_df.rename(columns={'type_VirtualRide': 'type_virtualride'})
segments_df.head(5)
# Out:
#          id  activity_id  athlete_id  \
# 0  24674235   4831255939    10944546
# 1  27141377   4831057316    10944546
# 2  22501195   4818094466    10944546
# 3   3566434   4818094466    10944546
# 4  20598228   4818094466    10944546
#
#                                                 name  elapsed_time  \
# 0                                     Champs-Élysées           653
# 1  Epic KOM - Start to Bypass Intersection (Zwift...           424
# 2                              Villenave-Technopole            789
# 3                               Col du Chateau d'eau           217
# 4                         Col du chateau d'eau court           151
#
#    moving_time  distance  average_cadence  average_watts  average_grade  \
# 0          653   6623.10             82.3          202.8            0.0
# 1          424   1882.50             77.3          201.2            3.8
# 2          789   5100.50              NaN          108.0            0.5
# 3          217   1190.37              NaN          141.8            2.1
# 4          151    745.40              NaN          165.4            2.8
#
#    maximum_grade  climb_category  average_heart_rate  max_heart_rate  \
# 0            4.6               0               161.2           170.0
# 1           47.8               0               157.9           164.0
# 2            6.4               0               169.0           184.0
# 3            7.3               0               170.7           183.0
# 4            5.5               0               177.5           183.0
#
#   start_time  start_date  type_virtualride
# 0   18:46:25  2021-02-22                 1
# 1   18:19:40  2021-02-22                 1
# 2   14:39:32  2021-02-20                 0
# 3   14:40:47  2021-02-20                 0
# 4   14:42:02  2021-02-20                 0

# %%
segments_df['type_virtualride'].hist(bins=50, figsize=(5,2.5))
plt.show()

# %% [markdown]
# **Temps passé(min) last 30 days en fonction de Home Trainer ou pas**

# %%
time_virtual_last_30d = []
time_real_last_30d = []
for date in segments_df['start_date']:
    end_date = date - timedelta(days=1)
    start_date = end_date - timedelta(days=30)
    result = activities_df[activities_df['start_date'].between(start_date,end_date)]
    time_virtual = round((result.loc[result['type'] == 'VirtualRide']['elapsed_time'].sum()/60),2)
    time_real = round((result.loc[result['type'] == 'Ride']['elapsed_time'].sum()/60),2)
    time_virtual_last_30d.append(time_virtual) 
    time_real_last_30d.append(time_real)

# %%
segments_df['time_virtual_last_30d'] = time_virtual_last_30d
segments_df['time_real_last_30d'] = time_real_last_30d

# %%
plt.style.use('dark_background')
plt.figure(figsize=(15,8))
plt.plot(segments_df['start_date'],segments_df['time_real_last_30d'], color='green')
plt.plot(segments_df['start_date'],segments_df['time_virtual_last_30d'], color='red')
plt.xlabel('start_date')
plt.ylabel('time_elasped(min)')
plt.show()

# %%
segments_df.head(5)
# Out:
#          id  activity_id  athlete_id  \
# 0  24674235   4831255939    10944546
# 1  27141377   4831057316    10944546
# 2  22501195   4818094466    10944546
# 3   3566434   4818094466    10944546
# 4  20598228   4818094466    10944546
#
#                                                 name  elapsed_time  \
# 0                                     Champs-Élysées           653
# 1  Epic KOM - Start to Bypass Intersection (Zwift...           424
# 2                              Villenave-Technopole            789
# 3                               Col du Chateau d'eau           217
# 4                         Col du chateau d'eau court           151
#
#    moving_time  distance  average_cadence  average_watts  average_grade  \
# 0          653   6623.10             82.3          202.8            0.0
# 1          424   1882.50             77.3          201.2            3.8
# 2          789   5100.50              NaN          108.0            0.5
# 3          217   1190.37              NaN          141.8            2.1
# 4          151    745.40              NaN          165.4            2.8
#
#    maximum_grade  climb_category  average_heart_rate  max_heart_rate  \
# 0            4.6               0               161.2           170.0
# 1           47.8               0               157.9           164.0
# 2            6.4               0               169.0           184.0
# 3            7.3               0               170.7           183.0
# 4            5.5               0               177.5           183.0
#
#   start_time  start_date  type_virtualride  time_virtual_last_30d  \
# 0   18:46:25  2021-02-22                 1                 213.85
# 1   18:19:40  2021-02-22                 1                 213.85
# 2   14:39:32  2021-02-20                 0                 262.78
# 3   14:40:47  2021-02-20                 0                 262.78
# 4   14:42:02  2021-02-20                 0                 262.78
#
#    time_real_last_30d
# 0               101.4
# 1               101.4
# 2                 0.0
# 3                 0.0
# 4                 0.0
